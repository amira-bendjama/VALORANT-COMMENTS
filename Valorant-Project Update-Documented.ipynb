# %%
import pandas as pd

#read in list of youtubers from file

def get_channels_names(file_path):
    youtubers = pd.read_csv(file_path, sep = ",", header = 0)
    return youtubers

# %%
youtubers = get_channels_names("data/Youtubers_Half.csv")
youtubers
# Out:
#    channel_name sub_count                                    url    Name  \
# 0       Sykkuno     2.89M       https://www.youtube.com/@Sykkuno  Nicole
# 1    iiTzTimmy      1.63M     https://www.youtube.com/@iiTzTimmy  Nicole
# 2      Flights       918K      https://www.youtube.com/@Flightss  Nicole
# 3  QuarterJade       434K  https://www.youtube.com/@QuarterJade/  Nicole
# 4           red      329K   https://www.youtube.com/@RedValorant  Nicole
# 5       Ziptie       251K       https://www.youtube.com/@ZipTie/  Nicole
#
#            Type
# 0       variety
# 1       variety
# 2  all valorant
# 3       variety
# 4  all valorant
# 5  all valorant

# %%
from googleapiclient.discovery import build

#building youtube service
def youtube_build_service(YOUTUBE_API_SERVICE_NAME, 
                          YOUTUBE_API_VERSION,
                          KEY):
    return build(YOUTUBE_API_SERVICE_NAME,
                 YOUTUBE_API_VERSION,
                 developerKey=KEY)

# %%
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"
api_key = "YOUR_API_KEY"

youtube_service = youtube_build_service(YOUTUBE_API_SERVICE_NAME,
                                       YOUTUBE_API_VERSION, 
                                       api_key)
youtube_service

# %%
import requests
from bs4 import BeautifulSoup
import re

#Parse channel URL to return channel ID. Return URL.

def get_channel_id(channel_url):
    url ="" 
    #getting json
    resp = requests.get(channel_url)
    data = BeautifulSoup(resp.text, "html.parser")
    #finding "externalId" that has the channel id no matter what is link structure
    data_s = str(data)
    
    search_url = re.search('"externalId":',data_s)
    start, end = search_url.span()
    #finding the url after the id, using index
    for i in range(end , end+100):
        if data_s[i] == ",":
            break
        url += data_s[i]
    url = url.split('"')[1]
    return url

# %%
#Get statistics, snippet and contentDetails for Channel from YouTube API
##Documentation for returned values: https://developers.google.com/youtube/v3/docs/channels

def get_channel_details(youtube, **kwargs):
    return youtube.channels().list(
        part="statistics,snippet,contentDetails",
        **kwargs
    ).execute()

# %%
#Get channel details for specified list of youtubers. 
##Return channel_id, channel_title, channel_subscriber_count, channel_video_count, channel_view_count for each youtuber

def get_channels_details_info(youtubers, youtube_service):
    dict_youtubers = {}
    l_youtubers = []
    for index in range(len(youtubers["url"])):
        # get the channel ID from the URL
        channel_id= get_channel_id(youtubers["url"].iloc[index])
        # get the channel details
        response = get_channel_details(youtube_service, id=channel_id)
        snippet = response["items"][0]["snippet"]
        statistics = response["items"][0]["statistics"]
        dict_youtubers = {
            "channel_id":channel_id,
            "channel_title" : snippet["title"],
            "channel_subscriber_count" : statistics["subscriberCount"],
            "channel_video_count" : statistics["videoCount"],
            "channel_view_count"  : statistics["viewCount"] 
        }
        l_youtubers.append(dict_youtubers)
        
    return l_youtubers

# %%
#get channels info
##API CALL: QUOTA COUNT = 9
channels_info = get_channels_details_info(youtubers, youtube_service)
df_channel_info = pd.DataFrame(channels_info)

#save to csv file
df_channel_info.to_csv('data/channels_info.csv')
df_channel_info
# Out:
#                  channel_id channel_title channel_subscriber_count  \
# 0  UCRAEUAmW9kletIzOxhpLRFw       Sykkuno                  2890000
# 1  UC5v2QgY2D5tlu8uws23MG4Q     iiTzTimmy                  1630000
# 2  UCIfAlCwj-ZPZq5fqjpYDX3w       Flights                   918000
# 3  UC_wSuaxwUYsJOBZDWwHIQZg   QuarterJade                   434000
# 4  UCFJ1pr8iwWPeQjmeHnPhqvA           Red                   329000
# 5  UCQ8VQZoYPeXF_q0E19UDGYQ        Ziptie                   252000
#
#   channel_video_count channel_view_count
# 0                 640          371243211
# 1                 744          270583472
# 2                  56           96575008
# 3                 383           71185748
# 4                 294           53077841
# 5                 237           80884332

# %%
#Get video or channel information based on search parameter specified from YouTube API
##https://developers.google.com/youtube/v3/docs/search

def get_channel_videos(youtube, **kwargs):
    return youtube.search().list(
        **kwargs
    ).execute()

# %%
#Get snippet, contentDetails, statistics for video from YouTube API
##snippet property contains the channelId, title, description, tags, and categoryId properties
##https://developers.google.com/youtube/v3/docs/videos/list

def get_video_details(youtube, **kwargs):
    return youtube.videos().list(
        part="snippet,contentDetails,statistics",
        **kwargs
    ).execute()

# %%
#Takes video_response from get_video_details as argument. Parses response. 
# Returns dictionary containing : {
#         "Title": title,
#         "Channel Title": channel_title,
#         "Channel ID": channel_id
#         "Publish time": publish_time,
#         "Duration": duration_str,
#         "Number of comments": comment_count,
#         "Number of likes": like_count,
#         "Number of views": view_count
#     }

def video_infos(video_response):
     
    items = video_response.get("items")[0]
    # get the snippet, statistics & content details from the video response
    snippet         = items["snippet"]
    statistics      = items["statistics"]
    content_details = items["contentDetails"]
    # get infos from the snippet
    channel_title = snippet["channelTitle"]
    channel_id = snippet["channelId"]
    title         = snippet["title"]
    publish_time  = snippet["publishedAt"]
    
    # get stats infos
    comment_count = statistics["commentCount"]
    like_count    = statistics["likeCount"]
    view_count    = statistics["viewCount"]
    # get duration from content details
    duration = content_details["duration"]
    
    # duration in the form of something like 'PT5H50M15S'
    # parsing it to be something like '5:50:15'
    parsed_duration = re.search(f"PT(\d+H)?(\d+M)?(\d+S)?", duration).groups()
    duration_str = ""
    for d in parsed_duration:
        if d:
            duration_str += f"{d[:-1]}:"
    duration_str = duration_str.strip(":")
    
    dict_video_info = {
        "Title": title,
        "Channel Title": channel_title,
        "Channel ID": channel_id,
        "Publish time": publish_time,
        "Duration": duration_str,
        "Number of comments": comment_count,
        "Number of likes": like_count,
        "Number of views": view_count
        
    }
    
    return dict_video_info

# %%
#Returns videos from specified channel. Takes youtube_service, channel_id, video limit (default 5) as arguments
##Quota (for running get_channel_videos) = 101 per channel with video limit 5
##API CALLS: get_channel_videos, get_video_details

def get_videos_from_channel(youtube_service, channel_id, videos_limit = 5):

    # counting number of videos grabbed
    n_videos = 0
    next_page_token = None
    list_videos = []

    while n_videos < videos_limit:
        #paramters to select the videos
        #only valorant related videos
        params = {
            'part': 'snippet',
            'q': 'valorant',
            'channelId': channel_id,
            'type': 'video',
        }
        
        if next_page_token:
            params['pageToken'] = next_page_token
        
        #getting channel videos based on parameters
        res = get_channel_videos(youtube_service, **params)

        #getting items
        channel_videos = res.get("items")
    
        for video in channel_videos:
            if n_videos >= videos_limit:
                break
                
            n_videos += 1
            video_id = video["id"]["videoId"]
            # easily construct video URL by its ID
            video_url = f"https://www.youtube.com/watch?v={video_id}"
            
            video_response = get_video_details(youtube_service, id=video_id)

            # get video details in dictionary
            dictionary_video = video_infos(video_response)
            dictionary_video["video_id"] = video_id
            dictionary_video["url"] = video_url 
            
            list_videos.append(dictionary_video)

        
        # if there is a next page, then add it to our parameters
        # to proceed to the next page
        if "nextPageToken" in res:
            next_page_token = res["nextPageToken"]
    return list_videos

# %%
#Loop through channel info data frame and retrieve videos for all listed channels
videos_retrieved = []
for channel_id in df_channel_info["channel_id"]:
     videos_retrieved.extend(get_videos_from_channel(youtube_service, channel_id))

videos_retrieved
# Out:
# next page
# next page
# next page
# next page
# next page
# next page
# [{'Title': 'We are the lowest-ranked team in this Valorant tournament but...',
#   'Channel Title': 'Sykkuno',
#   'Channel ID': 'UCRAEUAmW9kletIzOxhpLRFw',
#   'Publish time': '2021-12-26T15:00:09Z',
#   'Duration': '30:15',
#   'Number of comments': '400',
#   'Number of likes': '32336',
#   'Number of views': '769838',
#   'video_id': 'Kl2XzD5DMoY',
#   'url': 'https://www.youtube.com/watch?v=Kl2XzD5DMoY'},
#  {'Title': 'Winning at Valorant by only going C',
#   'Channel Title': 'Sykkuno',
#   'Channel ID': 'UCRAEUAmW9kletIzOxhpLRFw',
#   'Publish time': '2022-11-20T18:47:39Z',
#   'Duration': '11:19',
#   'Number of comments': '192',
#   'Number of likes': '6592',
#   'Number of views': '92661',
#   'video_id': 'rMMFFE3BM5k',
#   'url': 'https://www.youtube.com/watch?v=rMMFFE3BM5k'},
#  {'Title': "I couldn't believe I did this 1v5 ACE!",
#   'Channel Title': 'Sykkuno',
#   'Channel ID': 'UCRAEUAmW9kletIzOxhpLRFw',
#   'Publish time': '2022-01-15T17:24:46Z',
#   'Duration': '10:20',
#   'Number of comments': '164',
#   'Number of likes': '15988',
#   'Number of views': '338205',
#   'video_id': 'hHyUOwruyZE',
#   'url': 'https://www.youtube.com/watch?v=hHyUOwruyZE'},
#  {'Title': "I CAN'T BELIEVE I DID THAT!! - Valorant with friends!",
#   'Channel Title': 'Sykkuno',
#   'Channel ID': 'UCRAEUAmW9kletIzOxhpLRFw',
#   'Publish time': '2020-08-11T17:00:11Z',
#   'Duration': '10:1',
#   'Number of comments': '296',
#   'Number of likes': '27636',
#   'Number of views': '777388',
#   'video_id': 'lKItvDga7Eo',
#   'url': 'https://www.youtube.com/watch?v=lKItvDga7Eo'},
#  {'Title': 'League of Legends player plays VALORANT',
#   'Channel Title': 'Sykkuno',
#   'Channel ID': 'UCRAEUAmW9kletIzOxhpLRFw',
#   'Publish time': '2020-04-11T14:34:54Z',
#   'Duration': '11:34',
#   'Number of comments': '192',
#   'Number of likes': '5196',
#   'Number of views': '108752',
#   'video_id': '9VYcATksKwU',
#   'url': 'https://www.youtube.com/watch?v=9VYcATksKwU'},
#  {'Title': 'I DROPPED A 41 KILL GAME IN RADIANT (Valorant)',
#   'Channel Title': 'iiTzTimmy',
#   'Channel ID': 'UC5v2QgY2D5tlu8uws23MG4Q',
#   'Publish time': '2022-11-27T23:00:32Z',
#   'Duration': '13:17',
#   'Number of comments': '50',
#   'Number of likes': '1867',
#   'Number of views': '58301',
#   'video_id': 'nHywtfQIwgw',
#   'url': 'https://www.youtube.com/watch?v=nHywtfQIwgw'},
#  {'Title': 'SHOULD I GO PRO IN VALORANT?',
#   'Channel Title': 'iiTzTimmy',
#   'Channel ID': 'UC5v2QgY2D5tlu8uws23MG4Q',
#   'Publish time': '2022-11-25T23:00:04Z',
#   'Duration': '8:8',
#   'Number of comments': '95',
#   'Number of likes': '1933',
#   'Number of views': '54429',
#   'video_id': '2_7Pro9m07E',
#   'url': 'https://www.youtube.com/watch?v=2_7Pro9m07E'},
#  {'Title': 'VALORANT FOR 65 HOURS: The Film | Solo Iron-Radiant in One Stream Challenge',
#   'Channel Title': 'iiTzTimmy',
#   'Channel ID': 'UC5v2QgY2D5tlu8uws23MG4Q',
#   'Publish time': '2021-11-30T22:00:02Z',
#   'Duration': '1:24:14',
#   'Number of comments': '3691',
#   'Number of likes': '131714',
#   'Number of views': '5103967',
#   'video_id': '6YESOZ_tGWo',
#   'url': 'https://www.youtube.com/watch?v=6YESOZ_tGWo'},
#  {'Title': 'PLAYING AGAINST THE MOST STACKED RADIANT TEAM EVER',
#   'Channel Title': 'iiTzTimmy',
#   'Channel ID': 'UC5v2QgY2D5tlu8uws23MG4Q',
#   'Publish time': '2022-11-26T23:00:30Z',
#   'Duration': '10:42',
#   'Number of comments': '32',
#   'Number of likes': '1592',
#   'Number of views': '43897',
#   'video_id': 'e8REhf2Feek',
#   'url': 'https://www.youtube.com/watch?v=e8REhf2Feek'},
#  {'Title': 'IITZTIMMY VS. SEN TENZ',
#   'Channel Title': 'iiTzTimmy',
#   'Channel ID': 'UC5v2QgY2D5tlu8uws23MG4Q',
#   'Publish time': '2022-08-26T00:35:31Z',
#   'Duration': '13:39',
#   'Number of comments': '172',
#   'Number of likes': '6315',
#   'Number of views': '206728',
#   'video_id': '4FgntfRhdQ4',
#   'url': 'https://www.youtube.com/watch?v=4FgntfRhdQ4'},
#  {'Title': 'This is what 5000 hours of Raze looks like on Valorant',
#   'Channel Title': 'Flights',
#   'Channel ID': 'UCIfAlCwj-ZPZq5fqjpYDX3w',
#   'Publish time': '2021-12-16T15:30:07Z',
#   'Duration': '7:2',
#   'Number of comments': '1803',
#   'Number of likes': '108591',
#   'Number of views': '3150668',
#   'video_id': '_ycFZvVLyJQ',
#   'url': 'https://www.youtube.com/watch?v=_ycFZvVLyJQ'},
#  {'Title': 'Confusing Radiant Streamers with Movement on Valorant',
#   'Channel Title': 'Flights',
#   'Channel ID': 'UCIfAlCwj-ZPZq5fqjpYDX3w',
#   'Publish time': '2022-05-24T14:00:35Z',
#   'Duration': '7:12',
#   'Number of comments': '2925',
#   'Number of likes': '119440',
#   'Number of views': '3424596',
#   'video_id': 'K60xur_5IIQ',
#   'url': 'https://www.youtube.com/watch?v=K60xur_5IIQ'},
#  {'Title': 'This is what a RADIANT Raze player looks like...',
#   'Channel Title': 'Flights',
#   'Channel ID': 'UCIfAlCwj-ZPZq5fqjpYDX3w',
#   'Publish time': '2022-04-06T14:29:16Z',
#   'Duration': '8:9',
#   'Number of comments': '1164',
#   'Number of likes': '54471',
#   'Number of views': '1439516',
#   'video_id': 'ORaNu0juKw4',
#   'url': 'https://www.youtube.com/watch?v=ORaNu0juKw4'},
#  {'Title': 'What 2000 hours of Aggressive plays look like on Valorant',
#   'Channel Title': 'Flights',
#   'Channel ID': 'UCIfAlCwj-ZPZq5fqjpYDX3w',
#   'Publish time': '2021-06-07T16:11:59Z',
#   'Duration': '9:1',
#   'Number of comments': '1001',
#   'Number of likes': '49687',
#   'Number of views': '1373600',
#   'video_id': 'k2ZV8ZKTXuo',
#   'url': 'https://www.youtube.com/watch?v=k2ZV8ZKTXuo'},
#  {'Title': 'The NEW FASTEST Valorant player...',
#   'Channel Title': 'Flights',
#   'Channel ID': 'UCIfAlCwj-ZPZq5fqjpYDX3w',
#   'Publish time': '2022-03-07T15:43:08Z',
#   'Duration': '8:8',
#   'Number of comments': '1128',
#   'Number of likes': '53099',
#   'Number of views': '1362132',
#   'video_id': 'CJFPeOEcbf0',
#   'url': 'https://www.youtube.com/watch?v=CJFPeOEcbf0'},
#  {'Title': 'Reyna instalocks Reyna',
#   'Channel Title': 'QuarterJade',
#   'Channel ID': 'UC_wSuaxwUYsJOBZDWwHIQZg',
#   'Publish time': '2022-10-16T20:17:34Z',
#   'Duration': '14:44',
#   'Number of comments': '130',
#   'Number of likes': '10526',
#   'Number of views': '203509',
#   'video_id': 'mI-xOHNYc0o',
#   'url': 'https://www.youtube.com/watch?v=mI-xOHNYc0o'},
#  {'Title': 'back to immortal',
#   'Channel Title': 'QuarterJade',
#   'Channel ID': 'UC_wSuaxwUYsJOBZDWwHIQZg',
#   'Publish time': '2022-08-10T20:35:30Z',
#   'Duration': '15:4',
#   'Number of comments': '84',
#   'Number of likes': '9512',
#   'Number of views': '177294',
#   'video_id': 'Ken8jHFMuaw',
#   'url': 'https://www.youtube.com/watch?v=Ken8jHFMuaw'},
#  {'Title': 'the craziest ace of my life',
#   'Channel Title': 'QuarterJade',
#   'Channel ID': 'UC_wSuaxwUYsJOBZDWwHIQZg',
#   'Publish time': '2022-03-17T20:40:31Z',
#   'Duration': '12:3',
#   'Number of comments': '96',
#   'Number of likes': '9039',
#   'Number of views': '165512',
#   'video_id': 'xNYgfGTzcRc',
#   'url': 'https://www.youtube.com/watch?v=xNYgfGTzcRc'},
#  {'Title': 'this is better than immortal gameplay',
#   'Channel Title': 'QuarterJade',
#   'Channel ID': 'UC_wSuaxwUYsJOBZDWwHIQZg',
#   'Publish time': '2022-09-30T19:06:25Z',
#   'Duration': '13:27',
#   'Number of comments': '100',
#   'Number of likes': '8112',
#   'Number of views': '146096',
#   'video_id': 'MqUA5gUOPjQ',
#   'url': 'https://www.youtube.com/watch?v=MqUA5gUOPjQ'},
#  {'Title': 'Best of QuarterJade - October 2022',
#   'Channel Title': 'QuarterJade',
#   'Channel ID': 'UC_wSuaxwUYsJOBZDWwHIQZg',
#   'Publish time': '2022-11-27T18:06:36Z',
#   'Duration': '19:4',
#   'Number of comments': '54',
#   'Number of likes': '4047',
#   'Number of views': '62177',
#   'video_id': '0jZX2ZakbJY',
#   'url': 'https://www.youtube.com/watch?v=0jZX2ZakbJY'},
#  {'Title': 'START YORU FLASHING LIKE THIS.... (100% better)',
#   'Channel Title': 'Red',
#   'Channel ID': 'UCFJ1pr8iwWPeQjmeHnPhqvA',
#   'Publish time': '2022-11-27T16:37:00Z',
#   'Duration': '8:2',
#   'Number of comments': '72',
#   'Number of likes': '2830',
#   'Number of views': '62060',
#   'video_id': 'j65QlUsU0gQ',
#   'url': 'https://www.youtube.com/watch?v=j65QlUsU0gQ'},
#  {'Title': 'Destroying people who think Yoru is bad in Valorant...',
#   'Channel Title': 'Red',
#   'Channel ID': 'UCFJ1pr8iwWPeQjmeHnPhqvA',
#   'Publish time': '2022-11-24T17:19:44Z',
#   'Duration': '8:17',
#   'Number of comments': '113',
#   'Number of likes': '2795',
#   'Number of views': '53551',
#   'video_id': 'xAGnbwIQ3t8',
#   'url': 'https://www.youtube.com/watch?v=xAGnbwIQ3t8'},
#  {'Title': 'NEW ION 2.0 SKINS ARE 100% AIMBOT in VALORANT (NO JOKE!)',
#   'Channel Title': 'Red',
#   'Channel ID': 'UCFJ1pr8iwWPeQjmeHnPhqvA',
#   'Publish time': '2022-10-18T19:03:15Z',
#   'Duration': '8:15',
#   'Number of comments': '256',
#   'Number of likes': '5844',
#   'Number of views': '169916',
#   'video_id': 'xsJsCuFk-GM',
#   'url': 'https://www.youtube.com/watch?v=xsJsCuFk-GM'},
#  {'Title': 'THE FORBIDDEN YORU STRATEGY...',
#   'Channel Title': 'Red',
#   'Channel ID': 'UCFJ1pr8iwWPeQjmeHnPhqvA',
#   'Publish time': '2022-10-25T15:12:57Z',
#   'Duration': '9:5',
#   'Number of comments': '106',
#   'Number of likes': '3867',
#   'Number of views': '86218',
#   'video_id': 'pRyFSFszEY0',
#   'url': 'https://www.youtube.com/watch?v=pRyFSFszEY0'},
#  {'Title': '"YORU THAT FLASH IS UNFAIR" (they were mad)',
#   'Channel Title': 'Red',
#   'Channel ID': 'UCFJ1pr8iwWPeQjmeHnPhqvA',
#   'Publish time': '2022-11-17T14:21:21Z',
#   'Duration': '8:8',
#   'Number of comments': '175',
#   'Number of likes': '2788',
#   'Number of views': '52314',
#   'video_id': 'TJH_AJwqjto',
#   'url': 'https://www.youtube.com/watch?v=TJH_AJwqjto'},
#  {'Title': 'Killing Streamers with the Griddy Swing',
#   'Channel Title': 'Ziptie',
#   'Channel ID': 'UCQ8VQZoYPeXF_q0E19UDGYQ',
#   'Publish time': '2022-11-25T13:00:03Z',
#   'Duration': '10:55',
#   'Number of comments': '651',
#   'Number of likes': '24228',
#   'Number of views': '571847',
#   'video_id': '6iGaCmbgxKw',
#   'url': 'https://www.youtube.com/watch?v=6iGaCmbgxKw'},
#  {'Title': "I Played Yoru for 485 Days Straight, Here's the Result...",
#   'Channel Title': 'Ziptie',
#   'Channel ID': 'UCQ8VQZoYPeXF_q0E19UDGYQ',
#   'Publish time': '2022-09-11T12:00:13Z',
#   'Duration': '11:1',
#   'Number of comments': '714',
#   'Number of likes': '28891',
#   'Number of views': '722395',
#   'video_id': 'tz8VBJs97D8',
#   'url': 'https://www.youtube.com/watch?v=tz8VBJs97D8'},
#  {'Title': 'The Two Most UNDERRATED Agents in Valorant…',
#   'Channel Title': 'Ziptie',
#   'Channel ID': 'UCQ8VQZoYPeXF_q0E19UDGYQ',
#   'Publish time': '2022-10-13T12:00:12Z',
#   'Duration': '10:47',
#   'Number of comments': '471',
#   'Number of likes': '11596',
#   'Number of views': '243665',
#   'video_id': 'yG2cNCs5csE',
#   'url': 'https://www.youtube.com/watch?v=yG2cNCs5csE'},
#  {'Title': 'Destroying RADIANT Streamers with Yoru…',
#   'Channel Title': 'Ziptie',
#   'Channel ID': 'UCQ8VQZoYPeXF_q0E19UDGYQ',
#   'Publish time': '2022-11-16T13:00:22Z',
#   'Duration': '11:44',
#   'Number of comments': '762',
#   'Number of likes': '11231',
#   'Number of views': '194967',
#   'video_id': 'i838OEsqP90',
#   'url': 'https://www.youtube.com/watch?v=i838OEsqP90'},
#  {'Title': 'Invisible Flashes are Destroying Valorant...',
#   'Channel Title': 'Ziptie',
#   'Channel ID': 'UCQ8VQZoYPeXF_q0E19UDGYQ',
#   'Publish time': '2022-11-09T13:00:14Z',
#   'Duration': '10:30',
#   'Number of comments': '485',
#   'Number of likes': '23824',
#   'Number of views': '699681',
#   'video_id': 'VVg_51Pmtos',
#   'url': 'https://www.youtube.com/watch?v=VVg_51Pmtos'}]

# %%
df_videos = pd.DataFrame(videos_retrieved)
#save to csv file
df_videos.to_csv('data/videos_info.csv')
df_videos
# Out:
#                                                 Title Channel Title  \
# 0   We are the lowest-ranked team in this Valorant...       Sykkuno
# 1                 Winning at Valorant by only going C       Sykkuno
# 2              I couldn't believe I did this 1v5 ACE!       Sykkuno
# 3   I CAN'T BELIEVE I DID THAT!! - Valorant with f...       Sykkuno
# 4             League of Legends player plays VALORANT       Sykkuno
# 5      I DROPPED A 41 KILL GAME IN RADIANT (Valorant)     iiTzTimmy
# 6                        SHOULD I GO PRO IN VALORANT?     iiTzTimmy
# 7   VALORANT FOR 65 HOURS: The Film | Solo Iron-Ra...     iiTzTimmy
# 8   PLAYING AGAINST THE MOST STACKED RADIANT TEAM ...     iiTzTimmy
# 9                              IITZTIMMY VS. SEN TENZ     iiTzTimmy
# 10  This is what 5000 hours of Raze looks like on ...       Flights
# 11  Confusing Radiant Streamers with Movement on V...       Flights
# 12   This is what a RADIANT Raze player looks like...       Flights
# 13  What 2000 hours of Aggressive plays look like ...       Flights
# 14                 The NEW FASTEST Valorant player...       Flights
# 15                             Reyna instalocks Reyna   QuarterJade
# 16                                   back to immortal   QuarterJade
# 17                        the craziest ace of my life   QuarterJade
# 18              this is better than immortal gameplay   QuarterJade
# 19                 Best of QuarterJade - October 2022   QuarterJade
# 20    START YORU FLASHING LIKE THIS.... (100% better)           Red
# 21  Destroying people who think Yoru is bad in Val...           Red
# 22  NEW ION 2.0 SKINS ARE 100% AIMBOT in VALORANT ...           Red
# 23                     THE FORBIDDEN YORU STRATEGY...           Red
# 24        "YORU THAT FLASH IS UNFAIR" (they were mad)           Red
# 25            Killing Streamers with the Griddy Swing        Ziptie
# 26  I Played Yoru for 485 Days Straight, Here's th...        Ziptie
# 27        The Two Most UNDERRATED Agents in Valorant…        Ziptie
# 28            Destroying RADIANT Streamers with Yoru…        Ziptie
# 29       Invisible Flashes are Destroying Valorant...        Ziptie
#
#                   Channel ID          Publish time Duration  \
# 0   UCRAEUAmW9kletIzOxhpLRFw  2021-12-26T15:00:09Z    30:15
# 1   UCRAEUAmW9kletIzOxhpLRFw  2022-11-20T18:47:39Z    11:19
# 2   UCRAEUAmW9kletIzOxhpLRFw  2022-01-15T17:24:46Z    10:20
# 3   UCRAEUAmW9kletIzOxhpLRFw  2020-08-11T17:00:11Z     10:1
# 4   UCRAEUAmW9kletIzOxhpLRFw  2020-04-11T14:34:54Z    11:34
# 5   UC5v2QgY2D5tlu8uws23MG4Q  2022-11-27T23:00:32Z    13:17
# 6   UC5v2QgY2D5tlu8uws23MG4Q  2022-11-25T23:00:04Z      8:8
# 7   UC5v2QgY2D5tlu8uws23MG4Q  2021-11-30T22:00:02Z  1:24:14
# 8   UC5v2QgY2D5tlu8uws23MG4Q  2022-11-26T23:00:30Z    10:42
# 9   UC5v2QgY2D5tlu8uws23MG4Q  2022-08-26T00:35:31Z    13:39
# 10  UCIfAlCwj-ZPZq5fqjpYDX3w  2021-12-16T15:30:07Z      7:2
# 11  UCIfAlCwj-ZPZq5fqjpYDX3w  2022-05-24T14:00:35Z     7:12
# 12  UCIfAlCwj-ZPZq5fqjpYDX3w  2022-04-06T14:29:16Z      8:9
# 13  UCIfAlCwj-ZPZq5fqjpYDX3w  2021-06-07T16:11:59Z      9:1
# 14  UCIfAlCwj-ZPZq5fqjpYDX3w  2022-03-07T15:43:08Z      8:8
# 15  UC_wSuaxwUYsJOBZDWwHIQZg  2022-10-16T20:17:34Z    14:44
# 16  UC_wSuaxwUYsJOBZDWwHIQZg  2022-08-10T20:35:30Z     15:4
# 17  UC_wSuaxwUYsJOBZDWwHIQZg  2022-03-17T20:40:31Z     12:3
# 18  UC_wSuaxwUYsJOBZDWwHIQZg  2022-09-30T19:06:25Z    13:27
# 19  UC_wSuaxwUYsJOBZDWwHIQZg  2022-11-27T18:06:36Z     19:4
# 20  UCFJ1pr8iwWPeQjmeHnPhqvA  2022-11-27T16:37:00Z      8:2
# 21  UCFJ1pr8iwWPeQjmeHnPhqvA  2022-11-24T17:19:44Z     8:17
# 22  UCFJ1pr8iwWPeQjmeHnPhqvA  2022-10-18T19:03:15Z     8:15
# 23  UCFJ1pr8iwWPeQjmeHnPhqvA  2022-10-25T15:12:57Z      9:5
# 24  UCFJ1pr8iwWPeQjmeHnPhqvA  2022-11-17T14:21:21Z      8:8
# 25  UCQ8VQZoYPeXF_q0E19UDGYQ  2022-11-25T13:00:03Z    10:55
# 26  UCQ8VQZoYPeXF_q0E19UDGYQ  2022-09-11T12:00:13Z     11:1
# 27  UCQ8VQZoYPeXF_q0E19UDGYQ  2022-10-13T12:00:12Z    10:47
# 28  UCQ8VQZoYPeXF_q0E19UDGYQ  2022-11-16T13:00:22Z    11:44
# 29  UCQ8VQZoYPeXF_q0E19UDGYQ  2022-11-09T13:00:14Z    10:30
#
#    Number of comments Number of likes Number of views     video_id  \
# 0                 400           32336          769838  Kl2XzD5DMoY
# 1                 192            6592           92661  rMMFFE3BM5k
# 2                 164           15988          338205  hHyUOwruyZE
# 3                 296           27636          777388  lKItvDga7Eo
# 4                 192            5196          108752  9VYcATksKwU
# 5                  50            1867           58301  nHywtfQIwgw
# 6                  95            1933           54429  2_7Pro9m07E
# 7                3691          131714         5103967  6YESOZ_tGWo
# 8                  32            1592           43897  e8REhf2Feek
# 9                 172            6315          206728  4FgntfRhdQ4
# 10               1803          108591         3150668  _ycFZvVLyJQ
# 11               2925          119440         3424596  K60xur_5IIQ
# 12               1164           54471         1439516  ORaNu0juKw4
# 13               1001           49687         1373600  k2ZV8ZKTXuo
# 14               1128           53099         1362132  CJFPeOEcbf0
# 15                130           10526          203509  mI-xOHNYc0o
# 16                 84            9512          177294  Ken8jHFMuaw
# 17                 96            9039          165512  xNYgfGTzcRc
# 18                100            8112          146096  MqUA5gUOPjQ
# 19                 54            4047           62177  0jZX2ZakbJY
# 20                 72            2830           62060  j65QlUsU0gQ
# 21                113            2795           53551  xAGnbwIQ3t8
# 22                256            5844          169916  xsJsCuFk-GM
# 23                106            3867           86218  pRyFSFszEY0
# 24                175            2788           52314  TJH_AJwqjto
# 25                651           24228          571847  6iGaCmbgxKw
# 26                714           28891          722395  tz8VBJs97D8
# 27                471           11596          243665  yG2cNCs5csE
# 28                762           11231          194967  i838OEsqP90
# 29                485           23824          699681  VVg_51Pmtos
#
#                                             url
# 0   https://www.youtube.com/watch?v=Kl2XzD5DMoY
# 1   https://www.youtube.com/watch?v=rMMFFE3BM5k
# 2   https://www.youtube.com/watch?v=hHyUOwruyZE
# 3   https://www.youtube.com/watch?v=lKItvDga7Eo
# 4   https://www.youtube.com/watch?v=9VYcATksKwU
# 5   https://www.youtube.com/watch?v=nHywtfQIwgw
# 6   https://www.youtube.com/watch?v=2_7Pro9m07E
# 7   https://www.youtube.com/watch?v=6YESOZ_tGWo
# 8   https://www.youtube.com/watch?v=e8REhf2Feek
# 9   https://www.youtube.com/watch?v=4FgntfRhdQ4
# 10  https://www.youtube.com/watch?v=_ycFZvVLyJQ
# 11  https://www.youtube.com/watch?v=K60xur_5IIQ
# 12  https://www.youtube.com/watch?v=ORaNu0juKw4
# 13  https://www.youtube.com/watch?v=k2ZV8ZKTXuo
# 14  https://www.youtube.com/watch?v=CJFPeOEcbf0
# 15  https://www.youtube.com/watch?v=mI-xOHNYc0o
# 16  https://www.youtube.com/watch?v=Ken8jHFMuaw
# 17  https://www.youtube.com/watch?v=xNYgfGTzcRc
# 18  https://www.youtube.com/watch?v=MqUA5gUOPjQ
# 19  https://www.youtube.com/watch?v=0jZX2ZakbJY
# 20  https://www.youtube.com/watch?v=j65QlUsU0gQ
# 21  https://www.youtube.com/watch?v=xAGnbwIQ3t8
# 22  https://www.youtube.com/watch?v=xsJsCuFk-GM
# 23  https://www.youtube.com/watch?v=pRyFSFszEY0
# 24  https://www.youtube.com/watch?v=TJH_AJwqjto
# 25  https://www.youtube.com/watch?v=6iGaCmbgxKw
# 26  https://www.youtube.com/watch?v=tz8VBJs97D8
# 27  https://www.youtube.com/watch?v=yG2cNCs5csE
# 28  https://www.youtube.com/watch?v=i838OEsqP90
# 29  https://www.youtube.com/watch?v=VVg_51Pmtos

# %%
#Get snippet for commentThread, flexible definition of arguments
##Response documentation https://developers.google.com/youtube/v3/docs/commentThreads/list

def get_comments(youtube, **kwargs):
    return youtube.commentThreads().list(
        part="snippet",
        **kwargs
    ).execute()

# %%
# #Returns a list of comment info :comments_dict = {
#                 "Comment ID":comment_id, 
#                 "Comment": comment,
#                 "Likes": like_count,
#                 "Replies": reply_count
#                 "Channel ID": channel_id
#                 "Video ID": videoId
#                 }
#Arguments: video_id, total_comments (default 100), max_comment_per_page (default 100), order (default by time))

##QUOTA USAGE FOR 1 URL: 6

def get_comments_video(videoId, total_comments = 100, max_comment_per_page = 100 , order = "time"):
    #count comments retrieved
    comments_nb = 0 

    #list to store comment dictionary
    list_comments = []
    #comment dictionary for storing comment data
    comments_dict = {}
    
    #while comment count less than total comment value get comments
    while comments_nb <total_comments:
       
        params = {
                'videoId': videoId, 
                'maxResults': max_comment_per_page,
                'order': 'relevance', # default is 'time' (newest)
            }

        response = get_comments(youtube_service, **params)

        items = response.get("items")


        # if items is empty, breakout of the loop
        if not items:
            break
        
        for item in items:
            #if comments_nb exceeds total_comments, break
            if comments_nb >= total_comments:
                break 
            #collect comment text, comment id, reply count, like count, channel id
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_id = item['snippet']['topLevelComment']['id']
            reply_count = item['snippet']['totalReplyCount']
            like_count = item['snippet']['topLevelComment']['snippet']['likeCount']

            #create dictionary with collected data and video idea
            comments_dict = {
                "Comment ID":comment_id, 
                "Comment": comment,
                "Likes": like_count,
                "Replies": reply_count,
                "Video ID": videoId
                }
            #increase comments_nb
            comments_nb+=1
            #add list_comments to comments_dict
            list_comments.append(comments_dict)

        #if nextPageToken exists, check next page    
        if "nextPageToken" in response:
            # if there is a next page
            # add next page token to the params we pass to the function
            params["pageToken"] =  response["nextPageToken"]
        else:
            # must be end of comments!!!!
            break
   
    return list_comments

# %%
#save dataframe to .csv file
def save_file(file_name, file_content):
    df_save = pd.DataFrame(file_content)
    df_save.to_csv("data/"+file_name+".csv")
    return df_save

# %%
comments = []

for video_id in df_videos["video_id"]:
    comments.extend(get_comments_video(video_id))

import json
with open('data/comments.json', 'w') as f:
    json.dump(comments, f)
# Out:
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next

# %%
#save to csv file
df_comments = save_file("comments", comments)
df_comments
# Out:
#                       Comment ID  \
# 0     Ugx-MyFNGwiUKZIWI1t4AaABAg
# 1     UgzWDQhfUdW3Si6omLl4AaABAg
# 2     UgzSYS98RNc4FGJBkHJ4AaABAg
# 3     Ugy-kpso2H9PZV7xo-94AaABAg
# 4     UgyrpTZOumJ9VvMrfhR4AaABAg
# ...                          ...
# 2600  UgxQ5p9xXS7WLN58bD14AaABAg
# 2601  Ugx_0-Qa_A1FstlxtJB4AaABAg
# 2602  UgwfLFmSHqRL38qCmW54AaABAg
# 2603  Ugwi-IB1Q_sEQq8bSW54AaABAg
# 2604  UgwPuXXOIoElQMPHvTN4AaABAg
#
#                                                 Comment  Likes  Replies  \
# 0     When you&#39;re the lowest team but you&#39;re...   3716       27
# 1     Their synergy was so good, and all of them pla...   3532        3
# 2     I can relate to this vid<br>My team: we’re win...   2003        3
# 3     Team Scarra had like the highest average in pl...   1571       19
# 4     Sykkuno be like : &quot;We are the lowest rank...   1448        0
# ...                                                 ...    ...      ...
# 2600  So, with ziptie and &quot;PRX Esoteric&quot; w...      0        0
# 2601                  OMG cant wait to play Yoru again!      0        1
# 2602  World&#39;s most cleverest and 999999 iq yoru ...      0        0
# 2603  I&#39;m pausing the video to try and find the ...      0        0
# 2604  I dont play valorant because our pc cant run i...      0        0
#
#          Video ID
# 0     Kl2XzD5DMoY
# 1     Kl2XzD5DMoY
# 2     Kl2XzD5DMoY
# 3     Kl2XzD5DMoY
# 4     Kl2XzD5DMoY
# ...           ...
# 2600  VVg_51Pmtos
# 2601  VVg_51Pmtos
# 2602  VVg_51Pmtos
# 2603  VVg_51Pmtos
# 2604  VVg_51Pmtos
#
# [2605 rows x 5 columns]

# %%
#join comment data to video data on video id
df_video_comment_data = pd.merge(df_videos, df_comments, how = 'outer', left_on = ['video_id'], right_on = ['Video ID'])
df_video_comment_data

df_video_comment_data.to_csv('data/comments_videos_info.csv')
